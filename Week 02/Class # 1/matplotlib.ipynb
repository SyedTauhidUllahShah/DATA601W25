# %% [markdown]
# #  Matplotlib
#
# ### DATA 601
#
# **Syed Tauhid Ullah Shah ([Syed.Tauhidullahshah@ucalgary.ca](mailto:Syed.Tauhidullahshahi@ucalgary.ca))**
#
#
#
# Matplotlib is a powerful plotting library for Python that allows you to create static, interactive, and animated visualizations. Combined with NumPy, you can efficiently generate and visualize complex data.
#
# This Notebook covers installation, basic plotting, customization, subplots, styling, animations, 3D plotting, saving figures, and more.
#
# ## Table of Contents
# 1. [Introduction to Matplotlib](#introduction)
# 2. [Installation](#installation)
# 3. [Basic Plotting](#basic-plotting)
# 4. [Plot Customization](#customization)
# 5. [Multiple Plots and Subplots](#subplots)
# 6. [Plotting Different Chart Types](#chart-types)
# 7. [Working with NumPy Data](#numpy-integration)
# 8. [Styling Plots](#styling)
# 9. [3D Plotting](#3d-plotting)
# 10. [Saving Figures](#saving)
# 11. [Conclusion and Further Resources](#conclusion)
#
#
# Further Reading:
# * **Python for Data Analysis** (third edition), by _Wes McKinney_ (Chapter 4). [Available online](https://wesmckinney.com/book/numpy-basics.html)
# - [Matplotlib Official Documentation](https://matplotlib.org/stable/contents.html)
# - [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) - Explore various plot examples.
# - [Matplotlib Tutorials on Real Python](https://realpython.com/python-matplotlib-guide/)

# %% [markdown]
# ## 1. Introduction to Matplotlib <a name="introduction"></a>
#
# Matplotlib is the most popular Python library for data visualization. It provides a MATLAB-like interface and supports a wide range of plots:
# - Line plots
# - Scatter plots
# - Bar charts
# - Histograms
# - Pie charts
# - 3D plots
# - Animations
#
# Matplotlib integrates well with NumPy for handling numerical data efficiently.

# %% [markdown]
# ## 2. Installation <a name="installation"></a>
#
# Install Matplotlib using `pip` or `conda`:
# ```bash
# pip install matplotlib
# # or
# conda install matplotlib
# ```
#
# Import Matplotlib and configure inline plotting if using Jupyter:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## 3. Basic Plotting <a name="basic-plotting"></a>
#
# Matplotlib's pyplot module provides a simple interface for creating plots.
#
# ### Creating a Simple Line Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some data using NumPy
x = np.linspace(0, 10, 100)       # 100 points from 0 to 10
y = np.sin(x)                     # sine of x

# Create a line plot
plt.figure(figsize=(8, 4))        # optional: set figure size
plt.plot(x, y)                    # plot y vs. x
plt.title("Simple Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)                    # add grid lines
plt.show()

# %% [markdown]
# ## 4. Plot Customization <a name="customization"></a>
#
# Customize plots by adjusting colors, styles, markers, and more.

# %%
# Using different line styles and markers
plt.figure(figsize=(8, 4))
plt.plot(x, y, color='red', linestyle='--', marker='o', label='sin(x)')
plt.title("Customized Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()      # display legend
plt.show()

# %% [markdown]
# ## 5. Multiple Plots and Subplots <a name="subplots"></a>
#
# Create multiple plots in one figure using subplots.

# %%
# Create two subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(x, np.sin(x), 'b-', label='sin(x)')
axes[0].set_title("Sine Wave")
axes[0].set_xlabel("x")
axes[0].set_ylabel("sin(x)")
axes[0].legend()

axes[1].plot(x, np.cos(x), 'r-', label='cos(x)')
axes[1].set_title("Cosine Wave")
axes[1].set_xlabel("x")
axes[1].set_ylabel("cos(x)")
axes[1].legend()

plt.tight_layout()  # Adjusts subplot params for a neat layout
plt.show()

# %% [markdown]
# ## 6. Plotting Different Chart Types <a name="chart-types"></a>
#
# Matplotlib can create various chart types using different functions.

# %% [markdown]
# ### Scatter Plot

# %%
# Scatter plot: random points
x_scatter = np.random.rand(50)
y_scatter = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.figure(figsize=(6, 6))
plt.scatter(x_scatter, y_scatter, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.title("Random Scatter Plot")
plt.colorbar()  # show color scale
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 10, size=5)

plt.figure(figsize=(6, 4))
plt.bar(categories, values, color='skyblue')
plt.title("Bar Chart Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ### Histogram

# %%
data_hist = np.random.randn(1000)  # normal distribution

plt.figure(figsize=(6, 4))
plt.hist(data_hist, bins=30, color='green', alpha=0.7)
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # emphasize the second slice

plt.figure(figsize=(6, 6))
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Pie Chart")
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle.
plt.show()

# %% [markdown]
# ## 7. Working with NumPy Data <a name="numpy-integration"></a>
#
# Matplotlib works seamlessly with NumPy arrays. Here are some examples:

# %%
# Generate data using NumPy
x_num = np.linspace(0, 2*np.pi, 400)
y_num = np.sin(x_num**2)

# Plot using Matplotlib
plt.figure(figsize=(8, 4))
plt.plot(x_num, y_num)
plt.title("Plot of sin(x^2)")
plt.show()

# %% [markdown]
# ## 8. Styling Plots <a name="styling"></a>
#
# Matplotlib offers various ways to style plots to make them visually appealing.

# %%
plt.style.use('ggplot')  # Use a pre-defined style

plt.figure(figsize=(8, 4))
plt.plot(x, y, label='sin(x^2)')
plt.title("Styled Plot")
plt.xlabel("x")
plt.ylabel("sin(x^2)")
plt.legend()
plt.show()

# Reset style to default
plt.style.use('default')

# %% [markdown]
# ## 10. 3D Plotting <a name="3d-plotting"></a>
#
# Matplotlib supports 3D plotting via `mpl_toolkits.mplot3d`.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Create data for a 3D parametric curve
t = np.linspace(0, 10, 100)
x3d = np.sin(t)
y3d = np.cos(t)
z3d = t

ax.plot(x3d, y3d, z3d, label='3D curve')
ax.set_title("3D Line Plot")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")
ax.legend()

plt.show()

# %% [markdown]
# ## 11. Saving Figures <a name="saving"></a>
#
# Save plots to files for later use:

# %%
plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.title("Saving This Plot")
plt.savefig("sine_wave.png")  # Save as PNG
plt.savefig("sine_wave.pdf")  # Save as PDF
plt.close()  # Close the figure to free memory
